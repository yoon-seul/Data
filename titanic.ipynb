# %%
import pandas as pd
import numpy as np
import lightgbm as lgb

titanic = pd.read_csv("./train.csv")
test = pd.read_csv("./test.csv")
submission = pd.read_csv("./submission.csv")

# %%
feature=['Pclass','Age','Fare']
target=['Survived']

# %%
X_train=titanic[feature]
X_test=test[feature]
Y_train=titanic[target]

model = lgb.LGBMRegressor(random_state=777,n_estimators=1000)
model.fit(X_train,Y_train)
# Out:
# LGBMRegressor(n_estimators=1000, random_state=777)

# %%
new = submission.copy()
new['Survived'] = model.predict(X_test)
new.to_csv("submission.csv",index=False)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEnconder()
titanic['Sex']=le.fit_transform(titanic['Sex'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ca67f784638c> in <module>
#       1 from sklearn import preprocessing
# ----> 2 le = preprocessing.LabelEnconder()
#       3 titanic['Sex']=le.fit_transform(titanic['Sex'])
#
# AttributeError: module 'sklearn.preprocessing' has no attribute 'LabelEnconder'
